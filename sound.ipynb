# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/class2021Fall/blob/main/sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# parameter setting
amp = 1          # range [0.0, 1.0]
sr = 10000       # sampling rate, Hz
dur = 0.5        # in seconds
freq = 100.0     # sine frequency, Hz
phase = np.pi/2  # phase, radian

# %%
# generate samples
nSamp = sr * dur
samples = np.arange(1, nSamp+1)

# %%
# convert samples to time
t = samples/sr

# %%
# convert time to angle in radian
theta0 = t * 2*np.pi * freq

# %%
# shift angle by phase
theta = theta0 + phase

# %%
# generate signal by sin-phasor
s = amp * np.sin(theta)

# %%
# plot the entire signal
plt.plot(t, s, ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
# plot a certain of signals
sampleRng = np.arange(0,100)
plt.plot(t[sampleRng], s[sampleRng], ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
ipd.Audio(s, rate=10000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; dur = 1; freq = 440; phase = 0
s, t, theta = phasor_sine(amp, sr, dur, freq, phase)
ipd.Audio(s, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
amp = 1; sr = 10000; 

F  = 698.46 
D  = 587.33 
Eb = 622.25 
F  = 698.46 
Bb = 932.33

empty = np.empty(0)

tmp, t, theta= phasor_sine(amp, sr, 0.25, F, phase)
all = np.concatenate((empty, tmp))

tmp, t, theta = phasor_sine(amp, sr, 1, D, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, D, phase)
all = np.concatenate((all, tmp*0))

tmp, t, theta = phasor_sine(amp, sr, 0.25, D, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, Eb, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, F, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, D*2, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, D, phase)
all = np.concatenate((all, tmp*0))

tmp, t, theta = phasor_sine(amp, sr, 0.25, D*2, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, D, phase)
all = np.concatenate((all, tmp*0))

tmp, t, theta = phasor_sine(amp, sr, 0.75, Bb, phase)
all = np.concatenate((all, tmp))

# %%
ipd.Audio(all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
